# %% [markdown]
# # Check transcript and convert to CSV
# Standardize transcript rules, look for mistakes, and create clean CSV

# %%
import pandas as pd
import os
import re
EPISODE = 1 # Change as necessary

# %% [markdown]
# ## Run preliminary tests

# %%
def checkFile(file):
    '''Do a first run-through to catch any mistakes.'''
    with open(file) as f:
        for i, line in enumerate(f.readlines()):
            condition_1 = line.startswith('[')
            condition_2 = line.startswith('?')
            condition_3 = line.split(' ')[0].isupper()
            if not (condition_1 or condition_2 or condition_3):
                print('Line #{} is a problem'.format(i))
                print(line)

checkFile('data/clean_episode{:02d}.txt'.format(EPISODE))

# %% [markdown]
# ## Create helper functions

# %%
def inbrackets(text):
    assert ('[' in text and ']' in text) or ('[' not in text), ('Problem! ' + text)
    return ', '.join(re.findall('\[([^\]]+)\]', text))
def outbrackets(text):
    assert ('[' in text and ']' in text) or ('[' not in text), ('Problem! ' + text)
    first = re.sub('\[([^\]]+)\]', '', text) 
    return re.sub('  ', ' ', first).strip()

# %% [markdown]
# ## Parse transcript into dataframe
#
# Dataframe structure:
# * episode: #
# * line number: #
# * talking: person talking
# * talking_to: person spoken at
# * words: non-bracketed material
# * context: bracketed material
# * type: dialogue / sound / testimony / exclamation

# %%
allData = []
with open('data/clean_episode{:02d}.txt'.format(EPISODE)) as f:
    for i, line in enumerate(f.readlines()):
        d = {}
        d['episode'] = EPISODE
        d['line'] = i        
        if line.startswith('['):
            m = inbrackets(line)
            assert len(m) + 2 == len(line.strip()), 'Line #{} is a problem\n{} {}'.format(i, line, m)
            d['talking'] = None
            d['talking_to'] = None
            d['words'] = None
            d['context'] = m
            d['type'] = 'sound'
        else:
            lineA = line.split(': ')
            assert len(lineA) == 2, 'Line #{} is a problem\n{}'.format(i, line)
            speaking = lineA[0]
            if '[' not in speaking:
                d['talking'] = speaking.lower()
                d['talking_to'] = 'aside'
                d['type'] = 'testimony'
            else:
                d['talking'] = speaking.split(' ')[0].lower()
                m = inbrackets(speaking).lower()
                if m == 'in exclamation':
                    d['talking_to'] = 'self'
                    d['type'] = 'exclamation'
                else:
                    d['talking_to'] = m[3:] # drop 'to'
                    d['type'] = 'dialogue'
            cc = lineA[1]
            d['words'] = outbrackets(cc)
            d['context'] = inbrackets(cc)            
        allData.append(d)

df = pd.DataFrame(allData)

# %% [markdown]
# ## Last quality spot check and reorder columns

# %%
print(sorted([i for i in df.talking.unique() if not i is None]))
# Out:
# ['???', 'alexb', 'alexd', 'angelique', 'annie', 'bri', 'caelynn', 'caitlin', 'cassie', 'catherine', 'chris', 'colton', 'courtney', 'demi', 'devin', 'elyse', 'erika', 'erin', 'hannahb', 'hannahg', 'heather', 'jane', 'katie', 'kirpa', 'laura', 'nicole', 'nina', 'onyeka', 'revian', 'sydney', 'tahzjuan', 'tayshia', 'tracy', 'women']

# %%
print(sorted([i for i in df.talking_to.unique() if not i is None]))
# Out:
# ['???', 'alexb', 'alexd', 'all', 'angelique', 'annie', 'aside', 'bri', 'caelynn', 'caitlin', 'cassie', 'catherine', 'chris', 'colton', 'courtney', 'demi', 'devin', 'dog', 'elyse', 'erika', 'erin', 'hannahb', 'hannahg', 'heather', 'jane', 'katie', 'kirpa', 'laura', 'nicole', 'nina', 'onyeka', 'producer', 'revian', 'self', 'sydney', 'tahzjuan', 'tayshia', 'tracy', 'women']

# %%
m = ['line', 'type', 'context', 'talking', 'talking_to', 'words', 'episode']
df = df[m]
df.sample(50)
# Out:
#       line         type context    talking talking_to  \
# 713    713     dialogue          catherine     colton
# 342    342     dialogue             colton      laura
# 303    303    testimony             nicole      aside
# 718    718        sound  laughs       None       None
# 46      46     dialogue             colton      chris
# 416    416     dialogue             colton       erin
# 105    105     dialogue            caelynn     colton
# 231    231     dialogue             onyeka     colton
# 6        6    testimony              katie      aside
# 152    152     dialogue             cassie     colton
# 308    308     dialogue             colton      devin
# 654    654     dialogue            tayshia     colton
# 226    226     dialogue             colton     onyeka
# 13      13     dialogue              chris     colton
# 657    657     dialogue            caitlin      women
# 666    666     dialogue              alexd     colton
# 994    994     dialogue             colton      chris
# 25      25     dialogue              chris     colton
# 933    933     dialogue             colton    hannahb
# 1006  1006    testimony              devin      aside
# 950    950     dialogue             colton    hannahg
# 577    577     dialogue             colton    caelynn
# 444    444     dialogue                ???      women
# 72      72     dialogue            tayshia     colton
# 254    254     dialogue             colton    hannahb
# 333    333     dialogue             colton   producer
# 121    121     dialogue             colton     sydney
# 598    598     dialogue               erin      women
# 321    321     dialogue             colton       nina
# 373    373     dialogue             colton       jane
# 282    282     dialogue                ???      women
# 541    541     dialogue             colton      laura
# 552    552     dialogue             colton    hannahg
# 203    203     dialogue             colton   courtney
# 370    370     dialogue               jane     colton
# 723    723     dialogue             colton  catherine
# 945    945  exclamation              women       self
# 690    690     dialogue             colton      alexd
# 796    796     dialogue                ???      women
# 516    516     dialogue             colton      erika
# 70      70     dialogue            tayshia     colton
# 439    439    testimony            hannahb      aside
# 215    215     dialogue              alexd     colton
# 643    643     dialogue             colton      elyse
# 806    806     dialogue          catherine     onyeka
# 842    842    testimony           tahzjuan      aside
# 488    488     dialogue             colton       demi
# 917    917     dialogue            hannahb       self
# 160    160     dialogue                ???     cassie
# 182    182     dialogue            caitlin     colton
#
#                                                   words  episode
# 713                                   Yeah, absolutely.        1
# 342                                 You look fantastic.        1
# 303   Like, I had no idea, I didn't get the debutant...        1
# 718                                                None        1
# 46                          I remember my walkup still.        1
# 416                   You know how to make an entrance.        1
# 105                        So I am miss North Carolina.        1
# 231   You are going to kill it. You are going to kil...        1
# 6     Hi, my name is katie, 26 years old and I am fr...        1
# 152   I have so many butterflies. No, I literally ha...        1
# 308                                        How are you?        1
# 654                                         Right here.        1
# 226                                     Onyeka-chu-chu-        1
# 13         What's it like being announced the bachelor?        1
# 657                 Oh, my God, she's in the damn tree.        1
# 666                               Can you hold... This?        1
# 994                                               I do.        1
# 25                            It's cool to think about.        1
# 933                                               Yeah.        1
# 1006  Colton is a great match for me. I'm definitely...        1
# 950                       Hi. Hannah, may I borrow you?        1
# 577                        It's been good. How's yours?        1
# 444     It's not fair. Like, how do you look that good?        1
# 72    I'm freaking out but it's good. So I don't kno...        1
# 254                                          All right.        1
# 333               Man, I wish I could have told to her.        1
# 121                       Yes! that's awesome. See you.        1
# 598   I think that he needs to make that move becaus...        1
# 321                                 I heard "bachelor."        1
# 373        Okay. I couldn't tell that was photoshopped.        1
# 282                                            Come on!        1
# 541                                              Laura?        1
# 552                                                Yes.        1
# 203                             I'll save it for later?        1
# 370          You don't recognize the dog in that photo?        1
# 723                                      See you later.        1
# 945                                               Oh...        1
# 690                                       Yeah? Really?        1
# 796    Do you think that they'e having a confrontation?        1
# 516                                    No. Help me out.        1
# 70    My name is Tayshia. How nervous are you right ...        1
# 439       I mean, he's a stud. Like, he's a total stud.        1
# 215                                               My...        1
# 643   Here we go. Oh, she's giving me a good fight. ...        1
# 806   I know you think it was longer but it really w...        1
# 842   As I was walking away, Colton n was like, "oh,...        1
# 488                                               Okay.        1
# 917                                 Ugh, this is sucky.        1
# 160                                         How was it?        1
# 182                                 My name is Caitlin.        1

# %% [markdown]
# ## Convert dataframe to CSV

# %%
df.to_csv('data/episode{:02d}.csv'.format(EPISODE), index=False)

# %% [markdown]
# ## Combine all CSVs

# %%
l = []
for f in sorted(os.listdir('data')):
    if f.startswith('episode') and f.endswith('.csv'):
        print(f)
        df_t = pd.read_csv('data/' + f, index_col=None, header=0)
        l.append(df_t)
df_big = pd.concat(l, axis = 0, ignore_index = True)
df_big.to_csv('data/allData.csv', index=False)
# Out:
# episode01.csv
# episode02.csv
# episode03.csv
# episode04.csv
